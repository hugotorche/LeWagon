# %% [markdown]
# # Setup 💻 (do not forget to run these cells before starting 👇)

# %% [markdown]
# ## 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Loading Spotify dataset

# %%
df = pd.read_csv('https://storage.googleapis.com/introduction-to-data-science/spotify-dataset.csv')

# %% [markdown]
# ----------

# %% [markdown]
# # Your Assignement starts here 🔥

# %% [markdown]
# ## 1. Can you display the first 10 row of the dataset?

# %%
df.head(10)
# Out:
#    acousticness                                     artists  danceability  \
# 0         0.995                         ['Carl Woitschach']         0.708
# 1         0.994    ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                     ['Seweryn Goszczyński']         0.749
# 3         0.995                        ['Francisco Canaro']         0.781
# 4         0.990    ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
# 5         0.995  ['Felix Mendelssohn', 'Vladimir Horowitz']         0.424
# 6         0.956        ['Franz Liszt', 'Vladimir Horowitz']         0.444
# 7         0.988                         ['Carl Woitschach']         0.555
# 8         0.995              ['Francisco Canaro', 'Charlo']         0.683
# 9         0.846                     ['Seweryn Goszczyński']         0.674
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
# 5       352600  0.1200         0  6NxAf7M8DNHOBTmEd3JSO5             0.911
# 6       136627  0.1970         0  6O0puPuyrxPjDTHDUgsWI7             0.435
# 7       153967  0.4210         0  6OJjveoYwJdIt76y0Pxpxw             0.836
# 8       162493  0.2070         0  6OaJ8Bh7lsBeYoBmwmo2nh             0.206
# 9       111600  0.2050         0  6PrZexNb16cabXR8Q418Xc             0.000
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# 1    8    0.0763   -28.454     1
# 2    5    0.1190   -19.924     0
# 3    1    0.1110   -14.734     0
# 4   11    0.0980   -16.829     1
# 5    6    0.0915   -19.242     0
# 6   11    0.0744   -17.226     1
# 7    1    0.1050    -9.878     1
# 8    9    0.3370    -9.801     0
# 9    9    0.1700   -20.119     1
#
#                                              name  popularity release_date  \
# 0                     Singende Bataillone 1. Teil           0         1928
# 1        Fantasiestücke, Op. 111: Più tosto lento           0         1928
# 2                  Chapter 1.18 - Zamek kaniowski           0         1928
# 3   Bebamos Juntos - Instrumental (Remasterizado)           0   1928-09-25
# 4     Polonaise-Fantaisie in A-Flat Major, Op. 61           1         1928
# 5                     Scherzo a capriccio: Presto           0         1928
# 6  Valse oubliée No. 1 in F-Sharp Major, S. 215/1           0         1928
# 7                             Per aspera ad astra           0         1928
# 8                Moneda Corriente - Remasterizado           0   1928-10-03
# 9                   Chapter 1.3 - Zamek kaniowski           0         1928
#
#    speechiness    tempo  valence  year
# 0       0.0506  118.469   0.7790  1928
# 1       0.0462   83.972   0.0767  1928
# 2       0.9290  107.177   0.8800  1928
# 3       0.0926  108.003   0.7200  1928
# 4       0.0424   62.149   0.0693  1928
# 5       0.0593   63.521   0.2660  1928
# 6       0.0400   80.495   0.3050  1928
# 7       0.0474  123.310   0.8570  1928
# 8       0.1270  119.833   0.4930  1928
# 9       0.9540   81.249   0.7590  1928

# %% [markdown]
# ## 2. Are there any missing values in the dataset?

# %%
df.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %% [markdown]
# ## 3. How many songs are there in the dataset?

# %%
df['id'].unique().shape
# Out:
# (169909,)

# %% [markdown]
# ## 4. How many artists?

# %%
df['artists'].unique().shape
# Out:
# (33375,)

# %% [markdown]
# ## 5. What's the average duration of a song, in minutes?

# %%
df['duration_ms'].mean()
# Out:
# 231406.1589733328

# %%
millis=df['duration_ms'].mean()
millis = int(millis)
seconds=(millis/1000)%60
seconds = int(seconds)
minutes=(millis/(1000*60))%60
minutes = int(minutes)
hours=(millis/(1000*60*60))%24

print ("%d:%d" % (minutes, seconds))
# Out:
# 3:51

# %% [markdown]
# ## 6. Can you plot the distribution of the durations?

# %%
df['duration_min'] = (df['duration_ms']/(1000*60))%60

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169909 entries, 0 to 169908
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   acousticness      169909 non-null  float64
#  1   artists           169909 non-null  object
#  2   danceability      169909 non-null  float64
#  3   duration_ms       169909 non-null  int64
#  4   energy            169909 non-null  float64
#  5   explicit          169909 non-null  int64
#  6   id                169909 non-null  object
#  7   instrumentalness  169909 non-null  float64
#  8   key               169909 non-null  int64
#  9   liveness          169909 non-null  float64
#  10  loudness          169909 non-null  float64
#  11  mode              169909 non-null  int64
#  12  name              169909 non-null  object
#  13  popularity        169909 non-null  int64
#  14  release_date      169909 non-null  object
#  15  speechiness       169909 non-null  float64
#  16  tempo             169909 non-null  float64
#  17  valence           169909 non-null  float64
#  18  year              169909 non-null  int64
#  19  duration_min      169909 non-null  float64
# dtypes: float64(10), int64(6), object(4)
# memory usage: 25.9+ MB

# %%
import seaborn as sns
sns.set()

sns.distplot(df["duration_min"])

# %% [markdown]
# ## 7. [Follow-up] Can you make this plot more readable by removing outliers (extreme values)?

# %%
sub_df = df[df["duration_min"] < 10]

sns.distplot(sub_df["duration_min"])

# %% [markdown]
# We only remove 470 songs (out of almost 170k) and get a way more interesting plot!

# %% [markdown]
# ## 8. What are the top 10 longest songs (duration)?

# %%
df.sort_values(by='duration_min', ascending=False).head(10)
# Out:
#         acousticness                                  artists  danceability  \
# 72889          0.601                         ['Environments']        0.1590
# 10573          0.900                          ['Umm Kulthum']        0.4100
# 118777         0.891                          ['Umm Kulthum']        0.3450
# 46427          0.776                          ['Chuck Riley']        0.5320
# 117370         0.993                         ['Portugallien']        0.0644
# 118566         0.937            ['Franklin Delano Roosevelt']        0.6560
# 9104           0.983                          ['Umm Kulthum']        0.3960
# 137235         0.899  ['President Franklin Delano Roosevelt']        0.6320
# 32742          0.966                          ['Umm Kulthum']        0.4230
# 24790          0.993                          ['Umm Kulthum']        0.2990
#
#         duration_ms  energy  explicit                      id  \
# 72889       3557955   0.562         0  2rRuuVflvA23Fcl8KezNAF
# 10573       3551152   0.451         0  0AsT5HMyXuqa8qWMLv0YZb
# 118777      3523619   0.723         0  1gXsu5iZHLpUr1zvXEfOxw
# 46427       3432107   0.307         0  3n6ej62cDXOS7LAPLqC0Um
# 117370      3093226   0.132         0  7M2tLKFG4LJEx0rd0NqFAu
# 118566      3091373   0.356         0  4ZqyhM0W9AQL4PLnDsfdcM
# 9104        3089255   0.347         0  29vwEHUHBLN5FRaHcgyXXf
# 137235      2845675   0.181         0  0FxtVpSIbZ0W9LZfsGLHqh
# 32742       2819985   0.442         0  758alg1GlDt1RnagnDQwHH
# 24790       2713536   0.459         0  6k5CtWBhe73wLbwfMVdduO
#
#         instrumentalness  key  liveness  loudness  mode  \
# 72889           0.611000   10     0.107   -22.135     0
# 10573           0.000034    8     0.703   -10.213     0
# 118777          0.769000    9     0.393    -7.801     1
# 46427           0.000000    0     0.116   -20.451     1
# 117370          0.962000    3     0.144   -37.943     1
# 118566          0.001510    6     0.694   -14.367     1
# 9104            0.558000    3     0.949   -11.557     1
# 137235          0.438000    4     0.854   -17.225     1
# 32742           0.093700    0     0.853   -11.066     1
# 24790           0.855000    3     0.928   -11.941     1
#
#                                                   name  popularity  \
# 72889   The Psychologically Ultimate Seashore (16 rpm)          19
# 10573                                       Enta Oumry          26
# 118777                                  Naheg El Berda           0
# 46427                            Aladdin - Storyteller          41
# 117370                                          Anslag           0
# 118566       Address to Congress on Yalta - 03 01 1945           0
# 9104                            Yalle Kan Yshgek Anene           0
# 137235    State of the Union Address (January 7, 1943)           0
# 32742                                   Ghana El Rabea           0
# 24790                            Halet Layale El Qamar           0
#
#        release_date  speechiness    tempo  valence  year  duration_min
# 72889    1969-01-01       0.1600  129.863   0.0126  1969     59.299250
# 10573    1964-02-06       0.1260  118.125   0.4080  1964     59.185867
# 118777   1946-01-01       0.0996  115.550   0.2990  1946     58.726983
# 46427    2004-01-01       0.9210   77.781   0.4430  2004     57.201783
# 117370         1932       0.0583   72.482   0.0357  1932     51.553767
# 118566   1944-06-05       0.6810  122.394   0.4210  1944     51.522883
# 9104     1949-01-01       0.0675  113.761   0.3270  1949     51.487583
# 137235         1950       0.5970   83.242   0.4380  1950     47.427917
# 32742    1946-01-01       0.1340  111.337   0.3630  1946     46.999750
# 24790    1946-01-01       0.2120   68.206   0.3490  1946     45.225600

# %% [markdown]
# ## 9. How long would it take to listen to all the songs?

# %%
total_duration = df['duration_ms'].sum()

total_duration
# Out:
# 39317989065

# %%
total_duration = df['duration_ms'].sum()

print ("Number of days: ", int(total_duration * 1.157407e-8))
# Out:
# Number of days:  455

# %% [markdown]
# This length is expressed in milliseconds, let's convert to days!

# %% [markdown]
# ## 10. What are the top 10 most popular songs? We would like a DataFrame with only the columns `artists`, `name` and `popularity` as output!

# %%
df[['artists','name','popularity']].sort_values(by='popularity', ascending=False).head(10)
# Out:
#                                           artists  \
# 87942                              ['The Weeknd']
# 87940                   ['DaBaby', 'Roddy Ricch']
# 87949                    ['Powfu', 'beabadoobee']
# 87941  ['THE SCOTTS', 'Travis Scott', 'Kid Cudi']
# 87852                     ['Surf Mesa', 'Emilee']
# 87946                                   ['Drake']
# 87840                             ['Roddy Ricch']
# 87844                  ['BENEE', 'Gus Dapperton']
# 87943                          ['StaySolidRocky']
# 87951                                 ['6ix9ine']
#
#                                                     name  popularity
# 87942                                    Blinding Lights         100
# 87940                       ROCKSTAR (feat. Roddy Ricch)          99
# 87949  death bed (coffee for your head) (feat. beabad...          97
# 87941                                         THE SCOTTS          96
# 87852               ily (i love you baby) (feat. Emilee)          95
# 87946                                       Toosie Slide          95
# 87840                                            The Box          95
# 87844                                         Supalonely          95
# 87943                                         Party Girl          94
# 87951                                              GOOBA          94

# %% [markdown]
# ## 11. What is the most popular song before 2000?

# %%
filt = df['year'] < 2000


df.loc[filt].sort_values(by='popularity', ascending=False).head(1)
# Out:
#        acousticness         artists  danceability  duration_ms  energy  \
# 84241         0.543  ['The Police']          0.82       253920   0.452
#
#        explicit                      id  instrumentalness  key  liveness  \
# 84241         0  1JSTJqkT5qHq8MDJnJbRE1           0.00294    1    0.0714
#
#        loudness  mode                   name  popularity release_date  \
# 84241    -9.796     1  Every Breath You Take          83   1983-06-17
#
#        speechiness    tempo  valence  year  duration_min
# 84241       0.0348  117.401     0.74  1983         4.232

# %% [markdown]
# ## 12. Can you plot the distribution of `popularity`?

# %%
sns.distplot(df["popularity"])

# %% [markdown]
# ## 13. What are the top 10 artists in terms of number of songs?

# %%
df['artists'].value_counts().sort_values(ascending=False).head(10)
# Out:
# ['Эрнест Хемингуэй']      1215
# ['Francisco Canaro']       938
# ['Эрих Мария Ремарк']      781
# ['Ignacio Corsini']        620
# ['Frank Sinatra']          592
# ['Bob Dylan']              539
# ['The Rolling Stones']     512
# ['Johnny Cash']            502
# ['The Beach Boys']         491
# ['Elvis Presley']          488
# Name: artists, dtype: int64

# %% [markdown]
# ## 14. [Follow-up] can you make a bar chart out of this result?

# %%
df['artists'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')

# %% [markdown]
# ## 15. How many songs by key?

# %%
df['key'].value_counts(sort=False)
# Out:
# 0     21499
# 1     12816
# 2     18821
# 3      7185
# 4     12921
# 5     16336
# 6      8586
# 7     20757
# 8     10711
# 9     17628
# 10    12056
# 11    10593
# Name: key, dtype: int64

# %% [markdown]
# ## 16. [Follow-up] Can you plot a bar chart using Seaborn? Make sure the keys are sorted in a descending order.

# %%
order = df['key'].value_counts(sort=True).index

sns.countplot(data=df, x='key', order=order)

# %% [markdown]
# ## 17. Can you plot a line graph representing the annual number of songs since 1921?

# %%
df2 = pd.DataFrame(df['year'].value_counts(sort=False))

sns.lineplot(data=df2)

# %% [markdown]
# Last question! 👇

# %% [markdown]
# ## 18. Can you visually check if there is relationship between `year` and `popularity`?

# %%
sns.scatterplot(data=df, x="year", y="popularity")

# %% [markdown]
# It seems that the popularity score has increased through time....
